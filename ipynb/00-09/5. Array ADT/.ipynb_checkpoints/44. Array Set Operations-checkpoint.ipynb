// %% [markdown]
// # Array ADT
//
// + Union
// + Intersection
// + Difference
// + Set Memberships

// %% [markdown]
// ## Intersection
//
// ___
//
// Where we need to perform binary operation.
//
// We look at two cases:
//
// 1. Sorted Lists
// 2. Unsorted Lists.

// %% [markdown]
// ## Unsorted Lists
//
// ___
//
// Performing $\text {INTERSECTION}$ on two sets.
//
// What does it mean? We take common elements of A and B, and store them in C.
//
// Lets call this A
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&5\T&10\T&4\T&6  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \end{array}
// $$
//
//
// Lets call this B
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 12\T&4\T&7\T&2\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \end{array}
// $$
//
// To merge A and B into C sorted list
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \end{array}
// $$
//
// So this is a binary operation, that is we need two(2) arrays to perform the operation.  Other operations that require two arrays:
//
//
// #### Lets start
//
// Use $i$ for list $A$, $j$ for list $B$ and $k$ for list $C$. And $m$ will equal to length of $A$, and $n$ will equal to the length of $B$.
//
// Remember here we look for common elements in both A and B. and copy ONLY those to C.
//
// Look array at A, and start copying. But before copying, first check in B, if that element is in B,(ie. ts common), only then copy to C. Move the pointer of i to next element. If element of A and not in B, then also move pointer i move to next element in A.
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&5\T&10\T&4\T&6  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _i\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 12\T&4\T&7\T&2\T&5  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _j\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$ $$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// _k\T&\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$ $$
//
// Is $i(3)$ in $B$ ? No. Move along $i$.
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&5\T&10\T&4\T&6  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&_i\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 12\T&4\T&7\T&2\T&5  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _j\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$ $$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// _k\T&\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
// $$ $$
//
// Is $i(5)$ in $B$ ? Yes. Insert $j(5)$ into $C$ and move along $k$ and $i$; that is $C[k++] = A[i++];$.
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&5\T&10\T&4\T&6  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&_i\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 12\T&4\T&7\T&2\T&5  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _j\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$ $$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 5\T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&_k\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$ $$
//
// Is $i(10)$ in $B$ ? No. Move along 𝑖.
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&5\T&10\T&4\T&6  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&_i\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 12\T&4\T&7\T&2\T&5  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _j\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$ $$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 5\T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&_k\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
// $$ $$
//
// Is $i(4)$ in $B$ ? Yes. Insert $i(4)$ into $C$ and move along $k$ and $i$; that is $C[k++] = A[i++];$.
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&5\T&10\T&4\T&6  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T&_i \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 12\T&4\T&7\T&2\T&5  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _j\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$ $$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 5\T&4\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&_k\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
// And We stop as we reached the end of A.
// ____
// #### Analysis
//
//
// Total time taken is:
//
// So we searching for element of A in B, time taken, will be n times, and we doing that m times.
//
// $m\times{n}$
//
// And we will just use 1 variable, so replace $m$ with $n$
//
// $n\times {n}=n^2$
//
//
// $$\text {O} (n^2)$$
//
// This is quadratic, and very slow.

// %% [markdown]
// ## Sorted Lists
//
// ___
//
// Performing $\text {INTERSECTION}$ on two sets.
//
// Lets call this A
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&4\T&5\T&6\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \end{array}
// $$
//
//
// Lets call this B
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 2\T&4\T&5\T&7\T&12  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \end{array}
// $$
//
// To merge A and B into C sorted list
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \end{array}
// $$
//
// So this is a binary operation, that is we need two(2) arrays to perform the operation.  Other operations that require two arrays:
//
//
// #### Lets start
//
// Use $i$ for list $A$, $j$ for list $B$ and $k$ for list $C$. And $m$ will equal to length of $A$, and $n$ will equal to the length of $B$.
//
//
// Here we can use merge procedure. Remember with merging we look for smaller values and copy those smaller values, since we want to keep the result list sorted. However, here we want common items. So we only copy when we have the same items. The only CHANGE, is to COPY once, where the i and j are the same, BUT increment i and j, since they are the same. So not copy is they are not the same, and move pointer of the smaller one.
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&4\T&5\T&6\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _i\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 2\T&4\T&5\T&7\T&12  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _j\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// _k\T&\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// Is $i(3)$ < $j(2)$,No, $j$ is less. Move $j$ along only.
//
// $$\text {RESULT}$$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&4\T&5\T&6\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _i\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 2\T&4\T&5\T&7\T&12  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&_j\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// _k\T&\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// Is $i(3)$ < $j(4)$,Yes, $i$ is less. Move $i$ along only.
//
// $$\text {RESULT}$$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&4\T&5\T&6\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&_i\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 2\T&4\T&5\T&7\T&12  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&_j\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// _k\T&\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$ $$
//
// Is $i(4)$ < $j(4)$,Equal,Insert $j(4)$ into $C$ and move along $k$ and $i$ along as well $C[k++] = A[i++];$. And increment $j++$ as well.
//
// $$\text {RESULT}$$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&4\T&5\T&6\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&_i\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 2\T&4\T&5\T&7\T&12  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&_j\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 4\T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&_k\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$ $$
//
// Is $i(5)$ < $j(5)$,Equal,Insert $j(5)$ into $C$ and move along $k$ and $i$ along as well $C[k++] = A[i++];$. And increment $j++$ as well.
//
// $$\text {RESULT}$$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&4\T&5\T&6\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&_i\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 2\T&4\T&5\T&7\T&12  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&_j\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 4\T&5\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&_k\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$ $$
//
// Is $i(6)$ < $j(7)$,Yes, $i$ is less. Move $i$ along only.
//
// $$\text {RESULT}$$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&4\T&5\T&6\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T&_i \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 2\T&4\T&5\T&7\T&12  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&_j\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 4\T&5\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&_k\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$ $$
//
// Is $i(10)$ < $j(7)$,No, $i$ is less. Move $j$ along only.
//
// $$\text {RESULT}$$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&4\T&5\T&6\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T&_i \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 2\T&4\T&5\T&7\T&12  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T&_j \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 4\T&5\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&_k\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
// $$ $$
//
// Is $i(10)$ < $j(12)$,Yes, $i$ is less. Move $i$ along only.
//
// $$\text {RESULT}$$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&4\T&5\T&6\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 2\T&4\T&5\T&7\T&12  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T&_j \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 4\T&5\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&_k\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
// Stop as $i = length = m$, which is more than the items in list.
//
// ____
// #### Analysis
//
//
// Total time taken is:
//
// Similar to merging :
//
// $$\text {O} (m+n )$$
//
//
// And we will just use 1 variable, so replace $m$ with $n$
//
// $$\text {O} (n+n )$$
//
// $$\text {O} (2n )$$
//
// $$\theta (n )$$
//
// Much faster.

// %%
#include <iostream>
#include <climits>
#include <math.h>
using namespace std;

// %%
class Array{
private:
    int *A;
    int size;
    int length;
    void Swap (int *x, int *y);
public:
    Array(){
        size=10;
        A=new int[10];
        length = 0;
        
    }
    Array(int sz){
        size=sz;
        A=new int[sz];
        length = 0;
        
    }
    ~Array(){
        delete []A;
    }
    void Display();
    void Insert (int index, int x);
    void Merge(Array arr);
    void INTERSECTION_US(Array arr);
    void INTERSECTION_Sorted(Array arr);
    
}

// %%
void Array::Swap (int *x, int *y){
    int temp;
    temp =*x;
    *x=*y;
    *y = temp;
}

// %%
void Array::INTERSECTION_US(Array arrB){
    int *C= new int[10];
    
    int i=0;
    int j=0;
    int k=0;
    
    int m = length;
    int n = arrB.length;
    
    i=0;
    bool found =false;
    //Insert from A into C
    //But check if first exists in B
    while (i<m){
        while (j<10){
            if (A[i] == arrB.A[j])
            {
                C[k++] = A[i++];
                found=true;
                break;
            }
            j++;
       }
       if (found ==false) 
       {
         i++;
       }
       found =false;
       j=0;
    }    

    //Display
    cout<<"This is C"<<endl;
    for(int i=0; i<k;i++)
      cout<<C[i]<<" ";      
    cout<<endl;   
}

// %%
void Array::INTERSECTION_Sorted(Array arrB){
    int *C= new int[10];
    
    int i=0;
    int j=0;
    int k=0;
    
    int m = length;
    int n = arrB.length;
    
    while (i<m && j<n){
        if (A[i] < arrB.A[j])
            i++ ;      
        else if (arrB.A[j] < A[i] )
            j++;
        else   //equal
        {
            C[k++] = A[i++];
            j++ ;      
        }    
    }    
    
    //Display
    for(int i=0; i<k;i++)
      cout<<C[i]<<" ";      
    cout<<endl;   
}

// %%
void Array::Merge(Array arrB){
    int *C= new int[10];
    
    int i=0;
    int j=0;
    int k=0;
    
    int m = length;
    int n = arrB.length;
    
    while (i<m && j<n){
        if (A[i] < arrB.A[j])
            C[k++] = A[i++];
        else     
            C[k++] = arrB.A[j++];
    }    
    
    //Deal for items left over
    //i starts where left off above
    //global
    for(;i<m;i++){
        C[k++]=A[i];  
    }
    
    for(;j<n;j++){
        C[k++]=arrB.A[j];
    }


    //Display
    for(int i=0; i<10;i++)
      cout<<C[i]<<" ";      
    cout<<endl;   
}

// %%
void Array::Insert(int index, int x){
   if  (index>=0 && index<=length){
     for(int i=length-1;i>=index;i--)
         A[i+1]=A[i];
     A[index]=x;
     length++;  
   }
}

// %%
void Array::Display(){
    for(int i=0; i<length;i++)
      cout<<A[i]<<" ";      
    cout<<endl;      
}

// %%
Array arr(5);
arr.Insert(0,3);
arr.Insert(1,8);
arr.Insert(2,16);
arr.Insert(3,20);
arr.Insert(4,25);


Array arrB(5);
arrB.Insert(0,4);
arrB.Insert(1,10);
arrB.Insert(2,12);
arrB.Insert(3,22);
arrB.Insert(4,23);


arr.Display();
arrB.Display();
arr.Merge(arrB);
arr.Display();
// Out:
// 3 8 16 20 25
// 4 10 12 22 23
// 3 4 8 10 12 16 20 22 23 25
// 3 8 16 20 25

// %% [markdown]
// ## Unsorted INTERSECTION

// %%
Array arrAA(5);
arrAA.Insert(0,3);
arrAA.Insert(1,5);
arrAA.Insert(2,10);
arrAA.Insert(3,4);
arrAA.Insert(4,6);


Array arrBB(5);
arrBB.Insert(0,12);
arrBB.Insert(1,4);
arrBB.Insert(2,7);
arrBB.Insert(3,2);
arrBB.Insert(4,5);


arrAA.Display();
arrBB.Display();
arrAA.INTERSECTION_US(arrBB);
cout<<"This is A"<<endl;
arrAA.Display();
// Out:
// 3 5 10 4 6
// 12 4 7 2 5
// This is C
// 5 4
// This is A
// 3 5 10 4 6

// %% [markdown]
// ## Sorted INTERSECTION

// %%
Array arrAAA(5);
arrAAA.Insert(0,3);
arrAAA.Insert(1,4);
arrAAA.Insert(2,5);
arrAAA.Insert(3,6);
arrAAA.Insert(4,10);


Array arrBBB(5);
arrBBB.Insert(0,2);
arrBBB.Insert(1,4);
arrBBB.Insert(2,5);
arrBBB.Insert(3,7);
arrBBB.Insert(4,12);


arrAAA.Display();
arrBBB.Display();
arrAAA.INTERSECTION_Sorted(arrBBB);
cout<<"This is A"<<endl;
arrAAA.Display();
// Out:
// 3 4 5 6 10
// 2 4 5 7 12
// 4 5
// This is A
// 3 4 5 6 10
