// %% [markdown]
// # Trees
// +  What is max/min number nodes (Given Height)
// +  What is max/min Height nodes (Given Nodes)

// %% [markdown]
//  ##  What is max/min number nodes (Given Height)
//
//  ___
//
// We know height, we need to caculate nodes.
//
//
// Remember Height starts at 0.
//
// Here I know the height of BT, so what can be the:
//
// 1. Min number of nodes
// 2. Max number of nodes
//
// To make up a BT. Remember rules fr BT:
//
// Every tree must have a maximum of 2 children or min 0 children, in range 0, 1, 2
//
//
// $$Degree(T) = 2$$
// $$Children = {0,1,2}$$
//
//
//
// Where Height = 1:
//
// What is min/max nodes is required to reach height 1
//
// To get height of 1 , I can fit in 2 nodes minimum, and maximum I can fit in 3 nodes.
//
//
// ```
//                                         Height=1
//                                                                         Height
//                                 +-+                  +-+              + <----+ 0
//                                 +-+                  +-+              |
//                                 /                    /  \             |
//                                /                    /    \            |
//                               /                    /      \           |
//                              /                    /        \          |
//                            +-+                  +-+        +-+        |
//                            +-+                  +-+        +-+        v <----+ 1
//
//                                n=2                  n=3
//
//                                Min                  Max
//
// ```
//
// Where Height = 2:
//
// What is min/max nodes is required to reach height 2.
// To get height of 2 , I can fit in 3 nodes minimum, and maximum I can fit in 7 nodes.
//
//
// ```
//
//                                         Height=2
//
//                                 +-+                  +-+                Height
//                                 +-+                  +-+              + <----+ 0
//                                 /                    /  \             |
//                                /                    /    \            |
//                               /                    /      \           |
//                              /                    /        \          |
//                            +-+                  +-+        +-+        |
//                            +-+                  +-+        +-+        |<-----+ 1
//                            /                    / \         / \       +
//                           /                    /   \       /   \      |
//                          /                    /     \     /     \     |
//                         +-+                 +-+    +-+   +-+   +-+    |
//                         +-+                 +-+    +-+   +-+   +-+    v <----+ 2
//
//                           n=3                         n=7
//
//                           Min                         Max
//
// ```
//
// Where Height = 3:
//
// What is min/max nodes is required to reach height 3.
// To get height of 3 , I can fit in 4 nodes minimum, and maximum I can fit in 15 nodes.
//
//
// ```
//
//                                              Height=3
//
//                                 +-+                  +------------+                        Height
//                                 +-+                  +------------+                      + <----+ 0
//                                 /                    /             \                     |
//                                /                    /               \                    |
//                               /                    /                 \                   |
//                              /                    /                   \                  |
//                            +-+                  +-+                   +-+                |
//                            +-+                  +-+                   +-+                |<-----+ 1
//                            /                    / \                   / \                +
//                           /                    /   \                 /   \               |
//                          /                    /     \               /     \              |
//                         +-+                 +-+    +-+             +-+   +-+             |
//                         +-+                 +-+    +-+             +-+   +-+             v <----+ 2
//                        /                  / \        / \         / \       / \           +
//                       /                  /   \      /   \       /   \     /   \          |
//                      /                  /     \    /     \     /     \   /     \         |
//                     +-+               +-+    +-+ +-+    +-+  +-+    +-++-+    +-+        |
//                     +-+               +-+    +-+ +-+    +-+  +-+    +-++-+    +-+        v <----+ 3
//
//
//                     n=3                                   n=7
//
//                     Min                                   Max
//
// ```
//
// We do see a pattern here.

// %% [markdown]
// ## Min Nodes
//
// ___
//
// $$Min\;\; Nodes = h+1$$

// %% [markdown]
// ## Max Nodes
//
// ___
//
// For maximim we see the following:
//
// ```
//
//
//                            Height=3
//   Height
//    0  +                  +------------+                       Nodes
//       |                  +------------+                      + <---- 1
//       |                  /             \                     |
//       |                 /               \                    |
//       |                /                 \                   |
//       |               /                   \                  |
//    1  |             +-+                   +-+                |
//       |             +-+                   +-+                |<----- 2
//       |             / \                   / \                +
//       |            /   \                 /   \               |
//       |           /     \               /     \              |
//    2  |         +-+    +-+             +-+   +-+             |
//       |         +-+    +-+             +-+   +-+             v <---- 2^2
//       |       / \        / \         / \       / \           +
//       |      /   \      /   \       /   \     /   \          |
//       |     /     \    /     \     /     \   /     \         |
//       |   +-+    +-+ +-+    +-+  +-+    +-++-+    +-+        |
//    3  v   +-+    +-+ +-+    +-+  +-+    +-++-+    +-+        v <---- 2^3
//
//
//                               n=7
//
//                               Max
//
// ```
//
//
// $$Max = 1 +2^1 + 2^2+2^3=15$$
//
// This is a GP (Geometric Progression) series:
//
// $$a+ar+ar^2+ar^3+ ...+ ar^k$$
//
// And there is a formula for this:
//
// $$\frac{a(r^{k+1} - 1)}{r -1}$$
//
// Thus we get back to ourt series:
//
// $$1 +2^1 + 2^2+2^3+...+2^h$$
//
// Here we can say:
//
// 1. $a = 1$
// 2. $r = 2$
// 3. $k = h=3$
//
//
// $$\frac{1(2^{h+1} - 1)}{2 -1}$$
//
//
// $$\frac{1(2^{h+1} - 1)}{2 -1}$$
//
//
// $$2^{h+1}-1$$
//
//
// $$2^{3+1}-1$$
//
// $$2^{4}-1$$
//
// $$16-1$$
//
// $$15$$
//
// Max= sum of GP Series Terms
//
// $$Max\;\; Nodes = 2^{h+1}-1$$

// %% [markdown]
//  ##  What is max/min number Height (Given Nodes)
//
//  ___
//
// We know nodes, we need to caculate height.
//
//
// Here I know the nodes of BT, so what can be the:
//
// 1. Min number of height
// 2. Max number of height
//
// Where nodes = 3:
//
// What min/max height is required for when nodes = 3
//
// Having 3 nodes , I can get minimum height of 1, and maximum I get maximum height of 2.
//
//
// ```
//
//                                              Nodes=3
//                                                                         Height
//                                   +-+                      +-+        + <----+ 0
//                                   +-+                      +-+        |
//                                   /  \                     /          |
//                                  /    \                   /           |
//                                 /      \                 /            |
//                                /        \               /             |
//                              +-+        +-+           +-+             |
//                              +-+        +-+           +-+             v <----+ 1    Min
//                                                       /               +
//                                                      /                |
//                                                     /                 |
//                                                   +-+                 |
//                                                   +-+                 v <----+ 2    Max
//
//                                     h=1               h=2
//
//                                     Min               Max
//
// ```
//
//
// here nodes = 7:
//
// What min/max height is required for when nodes = 7
//
// Having 7 nodes , I can get minimum height of 2, and maximum I get maximum height of 6.
//
//
// ```
//
//                                Node=7
//
//                         +-+          +-+                                Height
//                         +-+          +-+                              + <----+ 0
//                         /  \            \                             |
//                        /    \            \                            |
//                       /      \            \                           |
//                      /        \            \                          |
//                    +-+        +-+          +-+                        |
//                    +-+        +-+          +-+                        |<-----+ 1
//                    / \         / \            \                       +
//                   /   \       /   \            \                      |
//                  /     \     /     \            \                     |
//                +-+    +-+   +-+   +-+          +-+                    |
//                +-+    +-+   +-+   +-+          +-+                    v <----+ 2   Min
//                                                    \                  +
//                                                     \                 |
//                         h=2                          \                |
//                                                     +-+               v <----+ 3
//                         Min                         +-+               +
//                                                         \             |
//                                                          \            |
//                                                           \           |
//                                                          +-+          v <----+ 4
//                                                          +-+          +
//                                                             \         |
//                                                              \        |
//                                                               \       |
//                                                              +-+      v <----+ 5
//                                                              +-+      +
//                                                                 \     |
//                                                                  \    |
//                                                                   \   |
//                                                                  +-+  v <----+ 6  Max
//                                                                  +-+
//
//                                                      h=6
//
//                                                      Max
// ```
//
//
// here nodes = 15:
//
// What min/max height is required for when nodes = 15
//
// Having 15 nodes , I can get minimum height of 3, and maximum I get maximum height of 14.
//
//
//
//                            Nodes=15
//                                                                                             Height
//                          +------------+            -+                                      + <---- 0
//                          +------------+            -+                                      |
//                          /             \             \                                     |
//                         /               \             \                                    |
//                        /                 \             \                                   |
//                       /                   \             \                                  |
//                     +-+                   +-+           +-+                                |<----- 1
//                     +-+                   +-+           +-+                                +
//                     / \                   / \             \                                |
//                    /   \                 /   \             \                               |
//                   /     \               /     \             \                              |
//                 +-+    +-+             +-+   +-+           +-+                             v <---- 2
//                 +-+    +-+             +-+   +-+           +-+                             +
//               / \        / \         / \       / \             \                           |
//              /   \      /   \       /   \     /   \             \                          |
//             /     \    /     \     /     \   /     \             \                         |
//           +-+    +-+ +-+    +-+  +-+    +-++-+    +-+             V                        v <---- 3      Min
//           +-+    +-+ +-+    +-+  +-+    +-++-+    +-+             ....goes on..            ....goes on
//                                                                     V                      |
//                                                                      \                     |
//                                                                       \                    |
//                            h=3                                       +-+                   v <---- 11
//                                                                      +-+                   +
//                            Min                                           V                 |
//                                                                           \                |
//                                                                            \               |
//                                                                           +-+              v <---- 12
//                                                                           +-+              +
//                                                                              V             |
//                                                                               \            |
//                                                                                \           |
//                                                                               +-+          v <---- 13
//                                                                               +-+
//                                                                                            +
//                                                                                  V         |
//                                                                                   \        |
//                                                                                    \       |
//                                                                                   +-+      v <---- 14    Max
//                                                                                   +-+
//                                                                      h=14
//
//                                                                      Max
// ```
//
//
// We do see a pattern here.

// %% [markdown]
// ## Max Nodes
//
// ___
//
// For n = 3, the max height was 2
//
// For n = 7, the max height was 6
//
// For n = 15, the max height was 14
//
// So the max height is one less than the nodes.
//
//
// $$Min Height = n-1$$
//
// And this is very similar to min nodes given the height formula ($Min Nodes = h+1$)

// %% [markdown]
// ## Min Nodes
//
// ___
//
// We have establised the min height formula is very similar to min nodes formula.
//
// We thus as confimrm, that the max nodes formula can be converted to the max height formula.
//
// (on the aside we can also see before we get answer, it will be $log_2{n}$)
//
// So we have the max nodes formula, and we can work out the max height formula from this:
//
// $$Max\;\; Nodes = 2^{h+1}-1$$
//
// $$n = 2^{h+1}-1$$
//
// $$n+1 = 2^{h+1}$$
//
// $$2^{h+1}=n+1 \;\; _\text{(change sides)}$$
//
// $$h+1=log_2(n+1)$$
//
// $$h=log_2(n+1)-1$$
//
//
// $$Min\;\;Height=log_2(n+1)-1$$

// %% [markdown]
// ## Number Nodes of  BT (Get Height)
// ___
//
// Given the number of nodes, what is min/max height:
//
//
// $$h+1\le{n}\le2^{h+1}-1 $$
//
//
// $$O(n)_{min}\;\;\;\;\;\;O(2^n)_{max}$$

// %% [markdown]
// ## Height of  BT (Get Number of Nodes)
// ___
//
// Given the height, what is min/max nodes:
//
//
// $$log_2(n+1)-1\le{h}\le{n-1} $$
// $$O(logn)_{min}\;\;\;\;\;\;O(n)_{max}$$
