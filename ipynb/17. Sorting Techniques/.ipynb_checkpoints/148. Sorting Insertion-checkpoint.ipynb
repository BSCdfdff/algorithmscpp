// %% [markdown]
// # Sorting Techniques
//
// ___
//
// + Bubble Sort
// + Insertion Sort
// + Selection Sort
// + Heap Sort
// + Merge Sort
// + Quick Sort
// + Tree Sort
// + Shell Sort
// + Count Sort
// + Bucket/Bin Sort
// + Radix Sort

// %% [markdown]
// ## Bubble Sort
//
// ___
// We have the following 5 elements in array, and need to apply Bubble sort:
// $$$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 8\T&5\T&7\T&3\T&2 \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _i\T&\T&\T&\ \\\hline
// \end{array}
// $$
//
// We will draw the array vertically:
//
// $$
// \begin{array}{l}
// {8}\\
// {5}\\
// {7}\\
// {3}\\
// {2}\\
// \end{array}
// $$
//
// Bubble sort work on two consecutive elements everytime, buy comparing which ic greater.
//
//
//
// 1. Lets compare: 8 is greater/less than 5?
// 2. Its greater, so 5 will move up, and 8 will move down. That is they will interchange places:
//
// $$
// \begin{array}{l}
// \left.
// \begin{array}{l}
// {8}\\
// {5}\\
// \end{array}
// \right\}
// 8\gt{5}\\
// \; {7}\\
// \; {3}\\
// \; {2}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {8}\\
// {7}\\
// {3}\\
// {2}\\
// \end{array}
// $$
//
//
// 3. Lets compare next two numbers: 8 is greater/less than 7?
// 4. Its greater, so 7 will move up, and 8 will move down. That is they will interchange places:
//
// $$
// \begin{array}{l}
// \; {5}\\
// \left.
// \begin{array}{l}
// {8}\\
// {7}\\
// \end{array}
// \right\}
// 8\gt{7}\\
// \; {3}\\
// \; {2}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {7}\\
// {8}\\
// {3}\\
// {2}\\
// \end{array}
// $$
//
// 5. Lets compare next two numbers: 8 is greater/less than 3?
// 6. Its greater, so 3 will move up, and 8 will move down. That is they will interchange places:
//
//
// $$
// \begin{array}{l}
// \; {5}\\
// \; {7}\\
// \left.
// \begin{array}{l}
// {8}\\
// {3}\\
// \end{array}
// \right\}
// 8\gt{3}\\
// \; {2}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {7}\\
// {3}\\
// {8}\\
// {2}\\
// \end{array}
// $$
//
// 7. Lets compare next two numbers: 8 is greater/less than 2?
// 8. Its greater, so 2 will move up, and 8 will move down. That is they will interchange places:
//
//
// $$
// \begin{array}{l}
// \; {5}\\
// \; {7}\\
// \; {3}\\
// \left.
// \begin{array}{l}
// {8}\\
// {2}\\
// \end{array}
// \right\}
// 8\gt{2}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {7}\\
// {3}\\
// {2}\\
// {8}\\
// \end{array}
// $$
//
// Some important notes
//
// 1. When all elements are compared, it is called a PASS.
// 2. Result of first PASS:
//     + one element is sorted that is 8.
//     + The largest element is sorted
//     + We have done four (4) comparison, if we have 5 numbers
//     + We have done four (4) swaps, if we have 5 numbers
//
//
// $$First Pass$$
//
//
// $$
// \begin{array}{l}
// \left.
// \begin{array}{l}
// {8}\\
// {5}\\
// \end{array}
// \right\}
// 8\gt{5}\\
// \; {7}\\
// \; {3}\\
// \; {2}\\
// \end{array}
// \;\;\;
// \begin{array}{l}
// \; {5}\\
// \left.
// \begin{array}{l}
// {8}\\
// {7}\\
// \end{array}
// \right\}
// 8\gt{7}\\
// \; {3}\\
// \; {2}\\
// \end{array}
// \;\;\;
// \begin{array}{l}
// \; {5}\\
// \; {7}\\
// \left.
// \begin{array}{l}
// {8}\\
// {3}\\
// \end{array}
// \right\}
// 8\gt{3}\\
// \; {2}\\
// \end{array}
// \;\;\;
// \begin{array}{l}
// \; {5}\\
// \; {7}\\
// \; {3}\\
// \left.
// \begin{array}{l}
// {8}\\
// {2}\\
// \end{array}
// \right\}
// 8\gt{2}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {7}\\
// {3}\\
// {2}\\
// {8}\\
// \end{array}
// $$
//
// 1. Then we will perform second pass:
// 2. Lets compare next two numbers: 5 is greater/less than 7?
// 3. No change, as 5 is less than 7:
//
//
// $$
// \begin{array}{l}
// \left.
// \begin{array}{l}
// {5}\\
// {7}\\
// \end{array}
// \right\}
// 5\lt{7}\\
// \; {3}\\
// \; {2}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {7}\\
// {3}\\
// {2}\\
// {8}\\
// \end{array}
// $$
//
//
// 4. Lets compare next two numbers: 7 is greater/less than 3?
// 5. Its greater, so 3 will move up, and 7 will move down. That is they will interchange places:
//
// $$
// \begin{array}{l}
// {5}\\
// \left.
// \begin{array}{l}
// {7}\\
// {3}\\
// \end{array}
// \right\}
// 7\gt{3}\\
// \; {2}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {3}\\
// {7}\\
// {2}\\
// {8}\\
// \end{array}
// $$
//
// 6. Lets compare next two numbers: 7 is greater/less than 2?
// 7. Its greater, so 2 will move up, and 7 will move down. That is they will interchange places:
//
// $$
// \begin{array}{l}
// {5}\\
// {3}\\
// \left.
// \begin{array}{l}
// {7}\\
// {2}\\
// \end{array}
// \right\}
// 7\gt{2}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {3}\\
// {2}\\
// {7}\\
// {8}\\
// \end{array}
// $$
//
// 2. Result of second PASS:
//     + Two elements is sorted that is 8,7.
//     + The largest elements is sorted
//     + We have done Three (3) comparison
//     + We have done Two (2) swaps, but maximum is Three(3)
//     + the last comparison between 2 numbers are not done, as it is already sorted.
//
//
// $$Second Pass$$
//
//
// $$
// \begin{array}{l}
// \left.
// \begin{array}{l}
// {5}\\
// {7}\\
// \end{array}
// \right\}
// 5\lt{7}\\
// \; {3}\\
// \; {2}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// \left.
// \begin{array}{l}
// {7}\\
// {3}\\
// \end{array}
// \right\}
// 7\gt{3}\\
// \; {2}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {3}\\
// \left.
// \begin{array}{l}
// {7}\\
// {2}\\
// \end{array}
// \right\}
// 7\gt{2}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {3}\\
// {2}\\
// {7}\\
// {8}\\
// \end{array}
// $$
//
// 1. Then we will perform third pass:
// 2. Lets compare next two numbers: 5 is greater/less than 3?
// 3. Its greater, so 3 will move up, and 5 will move down. That is they will interchange places:
//
//
// $$
// \begin{array}{l}
// \left.
// \begin{array}{l}
// {5}\\
// {3}\\
// \end{array}
// \right\}
// 5\gt{3}\\
// \; {2}\\
// \; {7}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {3}\\
// {5}\\
// {2}\\
// {7}\\
// {8}\\
// \end{array}
// $$
//
// 4. Lets compare next two numbers: 5 is greater/less than 2?
// 5. Its greater, so 2 will move up, and 5 will move down. That is they will interchange places:
// 6. We stop here
//
// $$
// \begin{array}{l}
// {3}\\
// \left.
// \begin{array}{l}
// {5}\\
// {2}\\
// \end{array}
// \right\}
// 5\gt{3}\\
// \; {7}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {3}\\
// {2}\\
// {5}\\
// {7}\\
// {8}\\
// \end{array}
// $$
//
//
// $$Third Pass$$
//
//
// $$
// \begin{array}{l}
// \left.
// \begin{array}{l}
// {5}\\
// {3}\\
// \end{array}
// \right\}
// 5\gt{3}\\
// \; {2}\\
// \; {7}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {3}\\
// \left.
// \begin{array}{l}
// {5}\\
// {2}\\
// \end{array}
// \right\}
// 5\gt{3}\\
// \; {7}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {3}\\
// {2}\\
// {5}\\
// {7}\\
// {8}\\
// \end{array}
// $$
//
// 1. Result of third PASS:
//     + Three elements is sorted that is 5,7,8.
//     + The largest elements is sorted
//     + We have done Two (2) comparisons
//     + We have done Two (2) swaps
//     + the last comparison are not done as 5,7,8 is already sorted.
//
//
// 1. Then we will perform fourth pass:
// 2. Lets compare next two numbers: 3 is greater/less than 2?
// 3. Its greater, so 2 will move up, and 3 will move down. That is they will interchange places:
//
//
// $$
// \begin{array}{l}
// \left.
// \begin{array}{l}
// {3}\\
// {2}\\
// \end{array}
// \right\}
// 3\gt{2}\\
// \; {5}\\
// \; {7}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {2}\\
// {3}\\
// {5}\\
// {7}\\
// {8}\\
// \end{array}
// $$
//
//
// $$Fourth Pass$$
//
//
// $$
// \begin{array}{l}
// \left.
// \begin{array}{l}
// {3}\\
// {2}\\
// \end{array}
// \right\}
// 3\gt{2}\\
// \; {5}\\
// \; {7}\\
// \; {8}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {2}\\
// {3}\\
// {5}\\
// {7}\\
// {8}\\
// \end{array}
// $$
//
//
// 1. Result of fourth PASS:
//     + All elements is sorted that is 2,3,5,7,8.
//     + The largest elements is sorted
//     + We have done One (1) comparisons
//     + We have done One (1) swaps
//     + the last comparison are not done as 3,5,7,8 is already sorted.
//
//
// Summary:
//
// 1. Total number of element:
//     $$n = 5$$
//
// 2. Total number of passes:
//     $$4 passes$$
//     $$n-1$$.
//
// 3. Total number of comparisons: from from end:
//
//     $$1+2+3..+ n-1=\frac{n(n-1)}{2}=O(n^2)$$
//     $$\text{sum of first natural numbers}$$
//     $$\text{polynomial formula}$$
//
//
// 4. Total(Maximum) number of swaps:same as above, if we count number from last to first:
//
//     $$1+2+3..+ n-1=\frac{n(n-1)}{2}=O(n^2)$$
//
//
//
// So,
//
// $$ \text{Comparisons} = O(n^2)$$
// $$ \text{Swap} = O(n^2)$$
//
//
// Why called Bubble sort? Smaller or lighter element rise to the top, just like bubbles. We also saw that to get the largest element to the last element, we can do it a in few passes. That may be an objective to get last element.

// %% [markdown]
// ## Let Code it
//
// ___
//
// 1. We have an array, and total number of elements
// 2. Adn we need to perform $n-1$ passes. and we use a for loop for this.
// ```
// for (i=0; i< n-1; i++{
// ...
// }
// ```
// 3. What do we do in each pass? if first element is j, we need to compare j + 1, that is first and next consecutive element. Adn repeat this. So we need one more loop for comparing the elements.
//
// ```
// for (j=0; j< n-1; j++{
// ...
// }
// ```
//
// 4.  From the above, j must compare until $n-1$. But that only happened in First Pass. We saw that in Second Pass, the number of comparisons decreased by 1. So the loop should then then also reduce by i.
//
// ```
// for (j=0; j< n-1-i; j++{
// ...
// }
// ```
//
// 5. That means in First pass i = 0, so number passes is equal to number elements, and in Second and future passes, the number of comparison, will decrease as number of elements descrease
//
// ```
// j< n-1-i
//
// ```
// 6. Inside the loop, we need to compare: A[j] with A[j+1], and if greater, we swap:
//
// ```
// if (A[j] < A[j+1])
//  Swap (A[j], A[j+1]);
//
// ```
// 7. On Aside: When you have two nested for loops, thne you get $n^2$.
//
//
//
//
// ```
// void BubbleSort(int A[], int n){
//
//     for (i=0; i< n-1; i++{
//      for (j=0; j< n-1-i; j++{
//        if (A[j] < A[j+1])
//             Swap (A[j], A[j+1]);
//        }
//     }
// }
// ```
//
// Lets visually see the first pass:

// %% [markdown]
// ## Visually...with code (Only First Pass)
//
// ____
//
// First pass: i = 0 ( and j =0)
//
// 1. Lets compare: 8 is greater/less than 5?
// 2. Its greater, so 5 will move up, and 8 will move down. That is they will interchange places:
//
// $$
// \begin{array}{l}
// \left.
// \begin{array}{l}
// _{i=0} & _{j=0}& {8}\\
// _{} & _{j+1} & {5}\\
// \end{array}
// \right\}
// 8\gt{5}\\
// {7}\\
// {3}\\
// {2}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {8}\\
// {7}\\
// {3}\\
// {2}\\
// \end{array}
// $$
//
//
// 3. Lets compare next two numbers: 8 is greater/less than 7?
// 4. Its greater, so 7 will move up, and 8 will move down. That is they will interchange places:
//
// $$
// \begin{array}{l}
// \;{5}\\
// \left.
// \begin{array}{l}
// _{j=1}&{8}\\
// _{j+1}&{7}\\
// \end{array}
// \right\}
// 8\gt{7}\\
// \; {3}\\
// \; {2}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {7}\\
// {8}\\
// {3}\\
// {2}\\
// \end{array}
// $$
//
// 5. Lets compare next two numbers: 8 is greater/less than 3?
// 6. Its greater, so 3 will move up, and 8 will move down. That is they will interchange places:
//
//
// $$
// \begin{array}{l}
// \; {5}\\
// \; {7}\\
// \left.
// \begin{array}{l}
// _{j=2}& {8}\\
// _{j+1}&{3}\\
// \end{array}
// \right\}
// 8\gt{3}\\
// \; {2}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {7}\\
// {3}\\
// {8}\\
// {2}\\
// \end{array}
// $$
//
// 7. Lets compare next two numbers: 8 is greater/less than 2?
// 8. Its greater, so 2 will move up, and 8 will move down. That is they will interchange places:
//
//
// $$
// \begin{array}{l}
// \; {5}\\
// \; {7}\\
// \; {3}\\
// \left.
// \begin{array}{l}
// _{j=3}&{8}\\
// _{j+1}&{2}\\
// \end{array}
// \right\}
// 8\gt{2}\\
// \end{array}
// \;\;\;\;
// \begin{array}{l}
// {5}\\
// {7}\\
// {3}\\
// {2}\\
// {8}\\
// \end{array}
// $$

// %% [markdown]
// ## Adaptive
//
// ____
//
// Its is not default adaptive.Again Adaptive means, that if list is already sorted, our time complexity should decrease. That ii, bubble sort should take less time, than in case, if we have a unsorted list.
//
// Lets see the following list. We can see it is already sorted.
//
// $$
// \begin{array}{l}
// {2}\\
// {3}\\
// {5}\\
// {7}\\
// {8}\\
// \end{array}
// $$
//
// If we perform Bubble Sort on this. Lets do first pass. That is 2 and 3 will be compared. Nop swapping wil take place. Then compared 3 and 5. No swapping.Then compared 5 and 7. No swapping. Then compared 7 and 8. No swapping.
//
// So we doing the inner for loop, and for the entire time, no swapping was done. And the reason why swapping was not done, is because all the elements is already sorted.
//
// That means after the FIRST pass no swapping was done. And we still need to perform n-1 passes. If we know that not swapping was done, we can use a flag, to indicate that the rest of the passes should not occur. So we can break oout of the main for loop, if this is the case.
//
// ```
// void BubbleSort(int A[], int n){
//     int flag;
//
//     for (i=0; i< n-1; i++{
//      flag=0;
//      for (j=0; j< n-1-i; j++){
//        if (A[j] < A[j+1]){
//             Swap (A[j], A[j+1]);
//             flag=1;
//        }
//       }
//      if (flag==0)
//          break;
// }
// ```
//
// But this flag, will prevent future passes, at any pass, not ony first pass. But if the list is already sorted, it will only happen (not making any future passes), after the first.
//
// Time complixity with this flag in place:
//
// Number of comparisons: $n-1
// Number of swap: 0
//
// Leads us to:
//
// $$ O(n)$$
//
// So Maximim Time for Sorting (When list is sorted):
//     $$O(n^2)$$
//
// So Minimum Time for Sorting (For unsorted List):
//     $$O(n)$$
//
// So we made it Adaptive.

// %% [markdown]
// ## Stable
//
// ____
//
// Lets look athe the following list, with duplicate elements:
//
//
// $$
// \begin{array}{l}
// {8}\\
// {8}\\
// {3}\\
// {5}\\
// {4}\\
// \end{array}
// $$
//
// First pass, we compare 8 and 8. No swap. Then 8 and 3 compares. Yes swap, and second 8 moves down, and 3 moves up. So, first 8 kept it position.
//
// So the order is not changed or duplicate elements. So it is stable

// %%
#include <iostream>
#include <climits>
#include <math.h>
#define INSERTION_OPERATOR operator<<
#define EXTRACTION_OPERATOR operator>>
#define ADDITION_OPERATOR operator+
using namespace std;

// %%
void  Swap (int *a, int *b){
    int temp;
    temp =*a;
    *a=*b;
    *b=temp;
};

// %%
void BubbleSort(int H[], int n){
    int flag;
    
    for (int i=0; i< n-1; i++){
      flag=0;
      for (int j=0; j< n-i-1; j++){
          if (H[j] > H[j+1]){
             Swap (&H[j], &H[j+1]);
             flag=1;
         } 
      }
      if (flag==0){
         cout<<"Sorted at "<<i+1<<" Pass."<<endl;   
         cout<<"i = "<<i<<endl;   
         break;
      }    
    }      
}

// %%
int A[] = {8,5,7,3,2};
int n= 5;
    
BubbleSort(A,n);

for (int i = 0; i<5;i++){
    cout<<A[i]<<" ";
}
cout<<endl;
// Out:
// 2 3 5 7 8
// @0x7fe247a4bb60

// %% [markdown]
// ## Sorted List
// ___

// %%
int B[] = {2,3,5,7,8};
int k= 5;
    
BubbleSort(B,k);

for (int i = 0; i<5;i++){
    cout<<B[i]<<" ";
}
cout<<endl;
// Out:
// Sorted at 1 Pass.
// i = 0
// 2 3 5 7 8

// %% [markdown]
// ## Partially Sorted List
// ___

// %%
int C[] = {3,2,5,7,8};
int l= 5;
    
BubbleSort(C,l);

for (int i = 0; i<5;i++){
    cout<<C[i]<<" ";
}
cout<<endl;
// Out:
// Sorted at 2 Pass.
// i = 1
// 2 3 5 7 8
