// %% [markdown]
// # Merge Sort
// ___
//
// + Merging two lists
// + Merging two lists in single array
// + Merging multiple listsSelection Sort

// %% [markdown]
// ## Merge Sort
//
// ___
//
// Merging is the process of combining two sorted lists, into a single sorted list.
//
//
// We have the following two sorted array, A with m elements, and B with n elements.
//
//
// $$
// \;\;\;A
// $$
// $$
// \begin{array}{l}
// _{i} & _{0} & {2}  & _{} \\
// _{ } & _{1} & {10} & _{} \\
// _{ } & _{2} & {18}  & _{} \\
// _{ } & _{3} & {20} & _{} \\
// _{ } & _{4} & {23}  & _{} \\
// \end{array}
// $$
// $$$$
// $$
// \;\;\;B
// $$
// $$
// \begin{array}{l}
// _{j} & _{0} & {4}  & _{} \\
// _{ } & _{1} & {9} & _{} \\
// _{ } & _{2} & {19}  & _{} \\
// _{ } & _{3} & {25} & _{} \\
// \end{array}
// $$
//
// Resultant array:
//
//
// $$
// \;\;\;C
// $$
// $$
// \begin{array}{l}
// _{k} & _{0} & {0}  & _{} \\
// _{ } & _{1} & {0}  & _{} \\
// _{ } & _{2} & {0}  & _{} \\
// _{ } & _{3} & {0}  & _{} \\
// _{ } & _{4} & {0}  & _{} \\
// _{ } & _{5} & {0}  & _{} \\
// _{ } & _{6} & {0}  & _{} \\
// _{ } & _{7} & {0}  & _{} \\
// _{ } & _{8} & {0}  & _{} \\
// \end{array}
// $$
//
// So we will be comparing elements one by one of the two list, and copy the smallest element to single sorted list.
//
//
// Procedure:
//
// 1. Compare A of i, with B of j. Which is smaller:A of i, which is 2.
// 2. Copy 2 to C, at index 0.
// 3. Move i and k to next element.
//
//
// $$
// \;\;\;A
// $$
// $$
// \begin{array}{l}
// _{} & _{0} & {2}  & _{} \\
// _{i} & _{1} & {10} & _{} \\
// _{ } & _{2} & {18}  & _{} \\
// _{ } & _{3} & {20} & _{} \\
// _{ } & _{4} & {23}  & _{} \\
// \end{array}
// $$
// $$$$
// $$
// \;\;\;B
// $$
// $$
// \begin{array}{l}
// _{j} & _{0} & {4}  & _{} \\
// _{ } & _{1} & {9} & _{} \\
// _{ } & _{2} & {19}  & _{} \\
// _{ } & _{3} & {25} & _{} \\
// \end{array}
// $$
//
// Resultant array:
//
//
// $$
// \;\;\;C
// $$
// $$
// \begin{array}{l}
// _{ } & _{0} & {2}  & _{} \\
// _{k} & _{1} & {0}  & _{} \\
// _{ } & _{2} & {0}  & _{} \\
// _{ } & _{3} & {0}  & _{} \\
// _{ } & _{4} & {0}  & _{} \\
// _{ } & _{5} & {0}  & _{} \\
// _{ } & _{6} & {0}  & _{} \\
// _{ } & _{7} & {0}  & _{} \\
// _{ } & _{8} & {0}  & _{} \\
// \end{array}
// $$
//
// 4. Repeat step 1 to 3. (this case  we copy 4). etc
// 5. Move j and k to next element.
//
// $$
// \;\;\;A
// $$
// $$
// \begin{array}{l}
// _{} & _{0} & {2}  & _{} \\
// _{i} & _{1} & {10} & _{} \\
// _{ } & _{2} & {18}  & _{} \\
// _{ } & _{3} & {20} & _{} \\
// _{ } & _{4} & {23}  & _{} \\
// \end{array}
// $$
// $$$$
// $$
// \;\;\;B
// $$
// $$
// \begin{array}{l}
// _{} & _{0} & {4}  & _{} \\
// _{j} & _{1} & {9} & _{} \\
// _{ } & _{2} & {19}  & _{} \\
// _{ } & _{3} & {25} & _{} \\
// \end{array}
// $$
//
// Resultant array:
//
//
// $$
// \;\;\;C
// $$
// $$
// \begin{array}{l}
// _{ } & _{0} & {2}  & _{} \\
// _{ } & _{1} & {4}  & _{} \\
// _{k} & _{2} & {0}  & _{} \\
// _{ } & _{3} & {0}  & _{} \\
// _{ } & _{4} & {0}  & _{} \\
// _{ } & _{5} & {0}  & _{} \\
// _{ } & _{6} & {0}  & _{} \\
// _{ } & _{7} & {0}  & _{} \\
// _{ } & _{8} & {0}  & _{} \\
// \end{array}
// $$
//
// And so we continue until Array C is filled.
//
//
// $$
// \;\;\;A
// $$
// $$
// \begin{array}{l}
// _{} & _{0} & {2}  & _{} \\
// _{} & _{1} & {10} & _{} \\
// _{} & _{2} & {18}  & _{} \\
// _{} & _{3} & {20} & _{} \\
// _{ } & _{4} & {23}  & _{} \\
// _{i} & _{5} & {}  & _{} \\
// \end{array}
// $$
// $$$$
// $$
// \;\;\;B
// $$
// $$
// \begin{array}{l}
// _{} & _{0} & {4}  & _{} \\
// _{} & _{1} & {9} & _{} \\
// _{} & _{2} & {19}  & _{} \\
// _{j} & _{3} & {25} & _{} \\
// \end{array}
// $$
//
// Resultant array:
//
//
// $$
// \;\;\;C
// $$
// $$
// \begin{array}{l}
// _{ } & _{0} & {2}  & _{} \\
// _{ } & _{1} & {4}  & _{} \\
// _{ } & _{2} & {9}  & _{} \\
// _{ } & _{3} & {10}  & _{} \\
// _{ } & _{4} & {18}  & _{} \\
// _{ } & _{5} & {19}  & _{} \\
// _{ } & _{6} & {20}  & _{} \\
// _{ } & _{7} & {23}  & _{} \\
// _{k} & _{8} & {0}  & _{} \\
// \end{array}
// $$
//
// After the last copy i moved to index 5 (null), k moved t index 8, and j is at index 25. So we still have uncopied element(s) in array B (this can also happen for array A), So:
//
// Copy remaining elements:
// + Array A
// + Array B
//
//
// $$
// \;\;\;C
// $$
// $$
// \begin{array}{l}
// _{ } & _{0} & {2}  & _{} \\
// _{ } & _{1} & {4}  & _{} \\
// _{ } & _{2} & {9}  & _{} \\
// _{ } & _{3} & {10}  & _{} \\
// _{ } & _{4} & {18}  & _{} \\
// _{ } & _{5} & {19}  & _{} \\
// _{ } & _{6} & {20}  & _{} \\
// _{ } & _{7} & {23}  & _{} \\
// _{ } & _{8} & {25}  & _{} \\
// _{k} & _{9} & {0}  & _{} \\
// \end{array}
// $$

// %% [markdown]
// ## Lets Code (Merging two arrays into Single array)
//
// ___
//
// 1. All indexes i, j , k are initialized = 0;
//
// ```
// int i, j, k
// i=j=k=0;
// ```
// 2. Everytime we need to compare A of i with Bo of j, and copy the smallest one to C. And increment indexes.
//
// ```
// if (A[i] < B[j])
//     C[k++] = A[i++];
// else
//     C[k++] = B[j++];
//
// ```
//
// 3. And the above process need to continue, until A or B is exhausted all it elements, that is i < m, AND j < n. Both has to be finished (not only one)
//
// ```
// while (i <m && j < n){}
//
// ```
// 4. But what if A or B have more elements (we have exited the while loop now). Then A/B cannot be compared with each other. We need need to copy (these elements are already sorted) these elements to , in the sorted order. We dont have starting point for i index, as it will be the point (value) where while loop exited.
//
// ```
// for (; i < m; i++)
// {
//  C[k++] = A[i];
// }
//
// for (; j < n; j++)
// {
//  C[k++] = B[j];
// }
//
// ```
//
//
//
// ```
// void Merge(int A[], int B[], int m, int n)
// {
//     int i, j, k
//     i=j=k=0;
//
//     while (i <m && j < n){
//         if (A[i] < B[j])
//             C[k++] = A[i++];
//         else
//             C[k++] = B[j++];
//     }
//
//     for (; i < m; i++)
//     {
//      C[k++] = A[i];
//     }
//
//     for (; j < n; j++)
//     {
//      C[k++] = B[j];
//     }
//
// ```

// %% [markdown]
// ## Time Taken
//
// ___
//
// Time Complexity:
//
// $$O(m+n)$$

// %% [markdown]
// ## Using a single array
//
// ___
//
// Using a single array, that will represent two lists. How is this possible?
// $$$$
//
// $$
// A=
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|}
// \hline
// 2\T&5\T&8\T&12\T&3\T&6\T&7\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7 \\\hline
// \end{array}
// $$
//
// $$$$
//
//
// From the above we can see tha eveything is sorted up till 12. So the first half represents the first list, and second half represents the second list.
//
// So two lists are there in a single array.
//
//
// Index 0 to 3 (List 1)
//
// Index 4 to 7 (List 2)
//
// So we need to merge the two, and the result should be stored in A. But we will use intermediary array B of same size:
//
// That means merging in not 'in place', we need extra space for merging.
//
//
// Lets call:
// + index 0, as low.
// + index 7, as high.
// + index 3, as mid.
//
//
// $$
// A=
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|}
// \hline
// _l\T&_\T&_\T&_{mid}\T&_\T&_\T&_\T&_h\\\hline
// 2\T&5\T&8\T&12\T&3\T&6\T&7\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7 \\\hline
// \end{array}
// $$
//
//
//
// So
// + First list is from l to mid
// + Second list is from mid+1 to h
//
//
// And merging we need array B of same size:
//
// $$
// B=
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|}
// \hline
// _{}\T&_{}\T&_{}\T&_{}\T&_{}\T&_{}\T&_{}\T&_{}  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7 \\\hline
// \end{array}
// $$
//
//
// And we have index i, j and k as before:
//
// $$
// A=
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|}
// \hline
// _l\T&_\T&_\T&_{mid}\T&_\T&_\T&_\T&_h\\\hline
// 2\T&5\T&8\T&12\T&3\T&6\T&7\T&10  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7 \\\hline
// _i\T&\T&\T&\T&j\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// B=
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|}
// \hline
// _{}\T&_{}\T&_{}\T&_{}\T&_{}\T&_{}\T&_{}\T&_{}  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7 \\\hline
// _k\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// So now we can compare A of i, with B of j, and copy the smallest element to B. And increment indexes.
//
// And we end up with the resultant array:
//
// $$
// B=
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|}
// \hline
// {2}\T&{3}\T&{5}\T&{6}\T&{7}\T&{8}\T&{10}\T&{12}  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7 \\\hline
// \end{array}
// $$

// %% [markdown]
// ## Lets code for single array
// ___
//
//
// ```
// void MergeSingleArray(int A[],int l, int mid, int h, int *B){
//
//     int i, j, k;
//     i=j=k=0;
//
//     C=new int[z];
//
//     while (i <m && j < n){
//         if (A[i] < B[j])
//             C[k++] = A[i++];
//         else
//             C[k++] = B[j++];
//     }
//
//     cout<<"Index i:"<<i<<endl;
//     cout<<"Index j:"<<j<<endl;
//
//     for (; i < m; i++)
//     {
//       C[k++] = A[i];
//       cout<<"Copy rest (Index i):"<<i<<endl;
//     }
//
//     for (; j < n; j++)
//     {
//      C[k++] = B[j];
//      cout<<"Copy rest (Index j):"<<j<<endl;
//     }
//
//
//     cout<<"Final Index i:"<<i<<endl;
//     cout<<"Final Index j:"<<j<<endl;
//
//     for (int i = 0; i<k;i++){
//        cout<<C[i]<<" ";
//     }
//     cout<<endl;
//
// }
//
// ```

// %% [markdown]
// ## Merging Multiple List (M-Way Merging)
//
// ___
//
// What if we have multiple Lists? How do we go about merging it..Lets explore
//
// Here is an exmaple of 4 sorted lists which we want to merge:
//
// ```
//
//                 A   B   C   D
//
//                 2   3   5   8
//                 5   6   9   16
//                 15  18  12  20
//
// ```
//
// And we compare the first element of each list
//
// ```
//                  A   B   C   D
//                 +--------------+
//                 |2   3   5   8 |
//                 +--------------+
//                  5   6   9   16
//                  15  18  12  20
//
// ```
//
//
// And copy to E, result array. So 2 will be copied as it is the smallest element.
//
// ```
//                  E
//                  2
//
//
// ```
//
// Then we exclude 2 (from list A), and increment index of A to next, and copy that index, and the elements of B, C and D:
//
//
// ```
//                 A   B   C   D
//
//                   +-----------+
//                 2 | 3   5   8 +
//               +---+ +---------+
//               | 5   |
//               +-----+
//
//                     6   9   16
//                 15  18  12  20
//
// ```
//
// So we compare, 5, 3, 5, 8. Which smaller? Its 3. So we copy 3 to E:
//
//
// ```
//                  E
//                  2
//                  3
// ```
//
//
// Then we exclude 3 (from List B), and increment index of B to next (%), and copy that index, and the elements of A, C and D:
//
// ```
//                            A   B   C   D
//                                  +------+
//                            2   3 | 5   8|
//                           +------+ +----+
//                           |5   6   |
//                           +--------+
//                                    9   16
//                            15  18  12  20
//
//
// ```
//
// So we compare, 5, 6, 5, 8. Which smaller? Its 5 (list A). So we copy 5 to E:
//
//
// ```
//                  E
//                  2
//                  3
//                  5
// ```
//
// So we merging 4 list into 1. So this is called 4-way merging. So m lists. its m-way merging.

// %% [markdown]
// ## Merging Multiple List (Two way Merging)
//
// ___
//
//
// Here is an exmaple of 4 sorted lists which we want to merge:
//
// ```
//
//                 A   B   C   D
//
//                 2   3   5   8
//                 5   6   9   16
//                 15  18  12  20
//
// ```
//
// We merge A and B, to E, and merge C and D to F, Then merge E and F to G.
//
// ```
//
//
//                              A   B   C   D
//
//                              2   3   5   8
//                              5   6   9   16
//                              15  18  12  20
//                               \  /    \  /
//                                \/      \/
//                                E        F
//                                -        -
//                                -        -
//                                -        -
//                                -        -
//                                \        /
//                                 \      /
//                                  \    /
//                                   \  /
//                                    \/
//                                    G
//
// ```
//
// As we selecing two list at time, its called 2 way merging. Or we can select any other 2 lists.

// %%
#include <iostream>
#include <climits>
#include <math.h>
#define INSERTION_OPERATOR operator<< 
#define EXTRACTION_OPERATOR operator>> 
#define ADDITION_OPERATOR operator+
using namespace std;

// %%
void Merge(int A[], int B[], int m, int n,int *C,int z){

    int i, j, k;
    i=j=k=0;
    
    C=new int[z];
    
    while (i <m && j < n){
        if (A[i] < B[j])
            C[k++] = A[i++];
        else
            C[k++] = B[j++];
    }
    
    cout<<"Index i:"<<i<<endl;
    cout<<"Index j:"<<j<<endl;
    
    for (; i < m; i++)
    {
      C[k++] = A[i];
      cout<<"Copy rest (Index i):"<<i<<endl;
    }

    for (; j < n; j++)
    {
     C[k++] = B[j];
     cout<<"Copy rest (Index j):"<<j<<endl;
    }
    
    
    cout<<"Final Index i:"<<i<<endl;
    cout<<"Final Index j:"<<j<<endl;
    
    for (int i = 0; i<k;i++){
       cout<<C[i]<<" ";
    }
    cout<<endl;
    
}

// %%
void MergeSingleArray(int A[],int l, int mid, int h, int *B){

    int i, j, k;
    i=0;
    j=mid+1;
    k=l;
    
    B=new int[h];
    
    while (i <=mid && j <= h){
        if (A[i] < A[j])
            B[k++] = A[i++];
        else
            B[k++] = A[j++];
    }
    
    cout<<"Index i:"<<i<<endl;
    cout<<"Index j:"<<j<<endl;
    
    for (; i <= mid; i++)
    {
      B[k++] = A[i];
      cout<<"Copy rest (Index i):"<<i<<endl;
    }

    for (; j <= h; j++)
    {
     B[k++] = A[j];
     cout<<"Copy rest (Index j):"<<j<<endl;
    }
    
    
    cout<<"Final Index i:"<<i<<endl;
    cout<<"Final Index j:"<<j<<endl;
    
    cout<<"This is B:"<<endl;
    
    for (int i = l; i<=h;i++){
       cout<<B[i]<<" ";
    }
    cout<<endl;
    
    //Copy B To A
    for (int i = l; i<=h;i++){
       A[i]=B[i];
    }
    
    
    cout<<"This is A:"<<endl;
     for (int i = l; i<=h;i++){
       cout<<A[i]<<" ";
    }
    cout<<endl;
    
}

// %%
int Q[] = {2,10,18,20,23};
int R[] = {4,9,19,25};
int m= 5;
int n=4;
int k=9;
int *C;

Merge(Q,R,m,n,C,k);

// for (int i = 0; i<k;i++){
//     cout<<C[i]<<" ";
// }
// cout<<endl;
// Out:
// Final Index i:5
// Final Index j:4
// 2 4 9 10 18 19 20 23 25

// %%
int T[] = {2,5,8,12,3,6,7,10};
int l= 0;
int mid=3;
int h=7;
int *B;

MergeSingleArray(T,l,mid,h,B);
// Out:
// Index i:3
// Index j:8
// Copy rest (Index i):3
// Final Index i:4
// Final Index j:8
// This is B:
// 2 3 5 6 7 8 10 12
// This is A:
// 2 3 5 6 7 8 10 12

// %%
?xt::xtensor

// %%
?std::vector
