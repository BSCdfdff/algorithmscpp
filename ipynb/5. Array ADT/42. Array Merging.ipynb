// %% [markdown]
// # Array ADT
//
// + Merging two arrays into sorted arrays

// %% [markdown]
// ## Our Array
//
// ___
//
// Size = 5
//
// Length = 5
//
// How to read the table:
//
// 1. First row contains the value(s)
// 2. Second row contains the index
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \end{array}
// $$

// %% [markdown]
// ## Merging
//
// ___
//
// Prerequisite: Lists must be sorted.
//
// Lets call this A
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \end{array}
// $$
//
//
// Lets call this B
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \end{array}
// $$
//
// To merge A and B into C sorted list
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \end{array}
// $$
//
// So this is a binary operation, that is we need two(2) arrays to perform the operation.  Other operations that require two arrays:
//
// 1. Append
// 2. Concat
// 3. Compare
// 4. Copy
//
// #### Lets start
//
// The code to copy has some pearls: We check that A is less than B, is so we copy A to C. We then need to move to the next item of A, and move to the next item of C. We can do the assignment and the moving to next element in one statement $C[k++] = A[i++];$ . And how do we deal with items that is left over from one list (where the other list has stopped already)? We need to read that list till end.
//
//
//
// Use $i$ for list $A$, $j$ for list $B$ and $k$ for list $C$. And $m$ will equal to length of $A$, and $n$ will equal to the length of $B$.
//
//
//
// $$ $$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _i\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _j\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// _k\T&\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
// $$$$
//
// $$\text {THIS IS THE START} $$
// $$$$
//
// Is $i(3)$ < $j(4)$,Yes, $i$ is less. Insert $i(3)$ into $C$ and move along $k$ and $i$ along as well $C[k++] = A[i++];$.
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&_i\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// _j\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&_k\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
// $$ $$
// Is $i(8)$ < $j(4)$,No, $j$ is less. Insert $j(8)$ into $C$ and move along $k$ and $j$ along as well $C[k++] = A[j++];$.
//
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&_i\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&_j\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&4\T&\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&_k\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
// $$ $$
// Is $i(8)$ < $j(10)$,Yes, $i$ is less. Insert $i(8)$ into $C$ and move along $k$ and $i$ along as well $C[k++] = A[i++];$.
//
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&_i\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&_j\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&4\T&8\T&\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&\T&_k\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$ $$
// Is $i(16)$ < $j(10)$,No, $j$ is less. Insert $j(10)$ into $C$ and move along $k$ and $j$ along as well $C[k++] = A[j++];$.
//
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&_i\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&_j\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&4\T&8\T&10\T&\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&\T&\T&_k\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// 3 4 8 10 12 16 20 22 23 25
//
// $$ $$
// Is $i(16)$ < $j(12)$,No, $j$ is less. Insert $j(12)$ into $C$ and move along $k$ and $j$ along as well $C[k++] = A[j++];$.
//
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&_i\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&_j\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&4\T&8\T&10\T&12\T&\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&\T&\T&\T&_k\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$ $$
// Is $i(16)$ < $j(22)$,Yes, $i$ is less. Insert $i(16)$ into $C$ and move along $k$ and $i$ along as well $C[k++] = A[i++];$.
//
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&_i\T& \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&_j\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&4\T&8\T&10\T&12\T&16\T&\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&\T&\T&\T&\T&_k\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// $$ $$
// Is $i(20)$ < $j(22)$,Yes, $i$ is less. Insert $i(20)$ into $C$ and move along $k$ and $i$ along as well $C[k++] = A[i++];$.
//
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T&_i \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&_j\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&4\T&8\T&10\T&12\T&16\T&20\T&\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&\T&\T&\T&\T&\T&_k\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$ $$
// Is $i(25)$ < $j(22)$,No, $j$ is less. Insert $j(22)$ into $C$ and move along $k$ and $j$ along as well $C[k++] = A[j++];$.
//
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T&_i \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T&_j \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&4\T&8\T&10\T&12\T&16\T&20\T&22\T&\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&\T&\T&\T&\T&\T&\T&_k\T& \\\hline
// \end{array}
// $$
//
//
// $$ $$
// Is $i(25)$ < $j(23)$,No, $j$ is less. Insert $j(22)$ into $C$ and move along $k$ and $j$ along as well $C[k++] = A[j++];$.
//
//
//
// $$\text {RESULT}$$
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 3\T&8\T&16\T&20\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T&_i \\\hline
// \end{array}
// $$
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|}
// \hline
// 4\T&10\T&12\T&22\T&23  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4 \\\hline
// \T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&4\T&8\T&10\T&12\T&16\T&20\T&22\T&23\T&  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T&_k \\\hline
// \end{array}
// $$
//
//
//
// But now j = n = length, that is it went pass the items we have. This is where we stop for j. Thats why in loop we say $while (j<n)$, then we do the merging. But how do we deal with rest of items of $i$. Since $i$ is defined outside while, it will still have its counter value, as we use a for loop to get the rest of items of $i$. The same will apply is the $i$ ended up been exhausted, then we would copy the remaining items of $B$.
//
//
//
// $$
// \newcommand\T{\Rule{0pt}{1em}{.3em}}
// \begin{array}{|r|r|r|r|r|r|r|r|r|r|}
// \hline
// 3\T&4\T&8\T&10\T&12\T&16\T&20\T&22\T&23\T&25  \\\hline
// _0\T&_1\T&_2\T&_3\T&_4\T&_5\T&_6\T&_7\T&_8\T&_9 \\\hline
// \T&\T&\T&\T&\T&\T&\T&\T&\T& \\\hline
// \end{array}
// $$
//
//
// ____
// #### Analysis
//
//
// Total time taken is:
//
// First time we given time complexity in two variable, $m$ and $n$.
// $$$$
//
// $$\theta (m+n)$$
//
// Wherever you see $m+n$ there is merging involved.

// %%
#include <iostream>
#include <climits>
#include <math.h>
using namespace std;

// %%
class Array{
private:
    int *A;
    int size;
    int length;
    void Swap (int *x, int *y);
public:
    Array(){
        size=10;
        A=new int[10];
        length = 0;
        
    }
    Array(int sz){
        size=sz;
        A=new int[sz];
        length = 0;
        
    }
    ~Array(){
        delete []A;
    }
    void Display();
    void Insert (int index, int x);
    void Merge(Array arr);
    
}

// %%
void Array::Swap (int *x, int *y){
    int temp;
    temp =*x;
    *x=*y;
    *y = temp;
}

// %%
void Array::Merge(Array arrB){
    int *C= new int[10];
    
    int i=0;
    int j=0;
    int k=0;
    
    int m = length;
    int n = arrB.length;
    
    while (i<m && j<n){
        if (A[i] < arrB.A[j])
            C[k++] = A[i++];
        else     
            C[k++] = arrB.A[j++];
    }    
    
    //Deal for items left over
    //i starts where left off above
    //global
    for(;i<m;i++){
        C[k++]=A[i];  
    }
    
    for(;i<n;i++){
        C[k++]=arrB.A[j];
    }


    //Display
    for(int i=0; i<10;i++)
      cout<<C[i]<<" ";      
    cout<<endl;   
}

// %%
void Array::Insert(int index, int x){
   if  (index>=0 && index<=length){
     for(int i=length-1;i>=index;i--)
         A[i+1]=A[i];
     A[index]=x;
     length++;  
   }
}

// %%
void Array::Display(){
    for(int i=0; i<length;i++)
      cout<<A[i]<<" ";      
    cout<<endl;      
}

// %%
Array arr(5);
arr.Insert(0,3);
arr.Insert(1,8);
arr.Insert(2,16);
arr.Insert(3,20);
arr.Insert(4,25);


Array arrB(5);
arrB.Insert(0,4);
arrB.Insert(1,10);
arrB.Insert(2,12);
arrB.Insert(3,22);
arrB.Insert(4,23);


arr.Display();
arrB.Display();
arr.Merge(arrB);
arr.Display();
// Out:
// 3 8 16 20 25
// 4 10 12 22 23
// 3 4 8 10 12 16 20 22 23 25
// 3 8 16 20 25
